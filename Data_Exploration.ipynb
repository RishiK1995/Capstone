# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
combined = pd.read_csv('combined.csv')
combined.drop(columns=['seas_id', 'tm_y', 'player_id'], inplace=True)
combined.dtypes
# Out:
# season             int64
# player            object
# pos               object
# age              float64
# tm_x              object
# g                  int64
# mp_per_game      float64
# pts_per_game     float64
# fg_per_game      float64
# fga_per_game     float64
# fg_percent       float64
# x3p_per_game     float64
# x3pa_per_game    float64
# x3p_percent      float64
# e_fg_percent     float64
# ft_per_game      float64
# fta_per_game     float64
# orb_per_game     float64
# drb_per_game     float64
# trb_per_game     float64
# ast_per_game     float64
# stl_per_game     float64
# blk_per_game     float64
# pf_per_game      float64
# pts_won          float64
# pts_max          float64
# mvp_share        float64
# mvp              float64
# team              object
# w                float64
# l                float64
# lg                object
# playoffs           int64
# tov_percent      float64
# usg_percent      float64
# ows              float64
# dws              float64
# ...

# %%
top_scorers = combined[combined['g'] > 65].sort_values('pts_per_game', ascending=False)
top_scorers.head(20)
# Out:
#        season             player pos   age tm_x   g  mp_per_game  \
# 2797     1987     Michael Jordan  SG  23.0  CHI  82         40.0
# 14919    2019       James Harden  PG  29.0  HOU  78         36.8
# 9650     2006        Kobe Bryant  SG  27.0  LAL  80         41.0
# 3529     1988     Michael Jordan  SG  24.0  CHI  82         40.4
# 14662    2020       James Harden  SG  30.0  HOU  68         36.5
# 18903    2024        Luka Dončić  PG  24.0  DAL  70         37.5
# 3877     1990     Michael Jordan  SG  26.0  CHI  82         39.0
# 1066     1980      George Gervin  SG  27.0  SAS  78         37.6
# 16878    2023        Joel Embiid   C  28.0  PHI  66         34.6
# 10175    2006      Allen Iverson  PG  30.0  PHI  72         43.1
# 3916     1993     Michael Jordan  SG  29.0  CHI  78         39.3
# 3541     1989     Michael Jordan  SG  25.0  CHI  81         40.2
# 17967    2023        Luka Dončić  PG  23.0  DAL  66         36.2
# ...

# %%
top_assists = combined[combined['g'] > 65].sort_values('ast_per_game', ascending=False)
top_assists.head(20)
# Out:
#        season         player pos   age tm_x   g  mp_per_game  pts_per_game  \
# 4160     1990  John Stockton  PG  27.0  UTA  78         37.4          17.2
# 4060     1991  John Stockton  PG  28.0  UTA  82         37.8          17.2
# 2065     1985   Isiah Thomas  PG  23.0  DET  81         38.1          21.2
# 3279     1988  John Stockton  PG  25.0  UTA  82         34.7          14.7
# 5438     1992  John Stockton  PG  29.0  UTA  82         36.6          15.8
# 4148     1989  John Stockton  PG  26.0  UTA  82         38.7          17.1
# 292      1984  Magic Johnson  PG  24.0  LAL  67         38.3          17.6
# 357      1989  Magic Johnson  PG  29.0  LAL  77         37.5          22.5
# 5180     1994  John Stockton  PG  31.0  UTA  82         36.2          15.1
# 304      1985  Magic Johnson  PG  25.0  LAL  77         36.1          18.3
# 317      1986  Magic Johnson  PG  26.0  LAL  72         35.8          18.8
# ...

# %%
combined.corr()['mvp']
# Out:
# C:\Users\kamda\AppData\Local\Temp\ipykernel_23120\1428102263.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   combined.corr()['mvp']
# season          -0.010117
# age              0.014164
# g                0.045035
# mp_per_game      0.079847
# pts_per_game     0.143808
# fg_per_game      0.137319
# fga_per_game     0.122882
# fg_percent       0.034526
# x3p_per_game     0.038205
# x3pa_per_game    0.036697
# x3p_percent      0.016491
# e_fg_percent     0.030789
# ft_per_game      0.159439
# fta_per_game     0.153732
# orb_per_game     0.057748
# drb_per_game     0.112678
# trb_per_game     0.099713
# ast_per_game     0.109132
# stl_per_game     0.089202
# blk_per_game     0.070381
# pf_per_game      0.027680
# pts_won          0.969257
# pts_max          0.977741
# mvp_share        0.994173
# ...

# %%
combined.corr()['mvp'].plot.bar()
# Out:
# C:\Users\kamda\AppData\Local\Temp\ipykernel_23120\3979457840.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   combined.corr()['mvp'].plot.bar()
# <Axes: >

# %%
sns.heatmap(combined.corr())
# Out:
# C:\Users\kamda\AppData\Local\Temp\ipykernel_23120\1270256343.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(combined.corr())
# <Axes: >

# %%
def scatterplots(columns, ncol=None, figsize=(15, 8)):
    if ncol is None:
        ncol = len(columns)
    nrow = int(np.ceil(len(columns) / ncol))
    fig, axes = plt.subplots(nrow, ncol, figsize=figsize, squeeze=False)
    fig.subplots_adjust(wspace=0.5, hspace=0.6)
    for i, col in enumerate(columns):
        ax = axes.flatten()[i]
        ax.scatter(x = col, y = 'mvp_share', data=combined, alpha=0.5)
        ax.set(xlabel=col, ylabel='MVP Share')
    nsubplots = nrow * ncol    
    for empty in range(i+1, nsubplots):
        axes.flatten()[empty].set_visible(False)

# %%
features = [x for x in combined.columns if x not in ['season', 'player', 'pos', 'tm_x', 'lg', 'team']]

# %%
scatterplots(features, ncol=4, figsize=(15, 15))
